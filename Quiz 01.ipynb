# %%
# Question 1
# What is the correct way to declare a variable in Python?
# a) var x = 5
# b) x = 5
# c) int x = 5
# d) declare x = 5

# Fill with the correct option: 

# Question 2
# What is the data type of the variable 'name' in the following code?
# name = "John"
# a) Integer
# b) Float
# c) String
# d) Boolean

# Fill with the correct option: 

# Question 3
# Which of the following is a valid variable name in Python?
# a) my_variable
# b) 1_variable
# c) variable$
# d) my-variable

# Fill with the correct option: 

# Question 4
# What will the following code output?
# x = 10
# y = 5
# print(x + y)
# a) 10
# b) 15
# c) "10 + 5"
# d) Error

# Fill with the correct option: 

# Question 5
# What is the result of the following expression?
# 10 / 3
# a) 3.3333333333333335
# b) 3
# c) 3.0
# d) 4

# Fill with the correct option: 

# Question 6
# Which of the following is a correct Python syntax to get the last element of a list 'my_list'?
# a) my_list[-1]
# b) my_list[last()]
# c) my_list.last()
# d) my_list[0]

# Fill with the correct option: 

# Question 7
# What is the output of the following code?
# x = 5
# y = 2
# print(x ** y)
# a) 7
# b) 10
# c) 25
# d) 3

# Fill with the correct option: 

# Question 8
# Which of the following data types is immutable in Python?
# a) List
# b) Dictionary
# c) Tuple
# d) Set

# Fill with the correct option: 

# Question 9
# What does the 'not' operator do in Python?
# a) Adds two numbers
# b) Subtracts two numbers
# c) Returns the opposite boolean value
# d) Returns the remainder of a division

# Fill with the correct option: 

# Question 10
# Which of the following is not a valid Python comment?
# a) // This is a comment
# b) # This is a comment
# c) ''' This is a comment '''
# d) """ This is a comment """

# Fill with the correct option: 

# Question 11
# What is the correct way to check if two variables are equal in Python?
# a) x == y
# b) x = y
# c) x != y
# d) x !== y

# Fill with the correct option: 

# Question 12
# Which of the following operators is used for exponentiation in Python?
# a) ^
# b) **
# c) //
# d) %

# Fill with the correct option: 

# Question 13
# What will be the result of the following code?
# x = 5
# y = 2
# print(x / y)
# a) 2.5
# b) 2
# c) 2.0
# d) 3

# Fill with the correct option: 

# Question 14
# Which of the following data types is mutable in Python?
# a) Tuple
# b) String
# c) List
# d) Set

# Fill with the correct option: 

# Question 15
# What is the result of the following expression?
# True or False
# a) True
# b) False
# c) Error
# d) None

# Fill with the correct option: 

# Question 16
# What does the 'and' operator do in Python?
# a) Returns True if one of the operands is True
# b) Returns False if one of the operands is False
# c) Returns True if both operands are True
# d) Returns True if both operands are False

# Fill with the correct option: 

# Question 17
# Which of the following is not a valid data type in Python?
# a) int
# b) real
# c) str
# d) bool

# Fill with the correct option: 

# Question 18
# What will the following code output?
# x = 10
# y = 3
# print(x // y)
# a) 3
# b) 3.3333333333333335
# c) 3.0
# d) 4

# Fill with the correct option: 

# Question 19
# Which of the following is a correct way to define a multiline string in Python?
# a) "This is a multiline string."
# b) 'This is a multiline string.'
# c) """This is a multiline string."""
# d) 'This is a \n multiline string.'

# Fill with the correct option: 

# Question 20
# What will be the output of the following code?
# x = 7
# if x > 5:
#     print("x is greater than 5")
# else:
#     print("x is less than or equal to 5")
# a) x is greater than 5
# b) x is less than or equal to 5
# c) Error
# d) None

# Fill with the correct option: 

# Question 21
# What will be the result of the following code?
# x = [1, 2, 3]
# y = x
# y.append(4)
# print(x)
# a) [1, 2, 3, 4]
# b) [1, 2, 3]
# c) [4]
# d) Error

# Fill with the correct option: 

# Question 22
# What is the output of the following code?
# x = 10
# y = 3
# print(x % y)
# a) 3
# b) 0
# c) 1
# d) 2

# Fill with the correct option: 

# Question 23
# Which of the following data types is unordered in Python?
# a) List
# b) Tuple
# c) String
# d) Dictionary

# Fill with the correct option: 

# Question 24
# What is the result of the following expression?
# 10 == "10"
# a) True
# b) False
# c) Error
# d) None

# Fill with the correct option: 

# Question 25
# What will be the output of the following code?
# x = 5
# y = 2
# print(x * y)
# a) 10
# b) 7
# c) 5
# d)

 2

# Fill with the correct option: 

# Question 26
# Which of the following is used for floor division in Python?
# a) /
# b) //
# c) %
# d) *

# Fill with the correct option: 

# Question 27
# What is the output of the following code?
# x = "Hello"
# print(x[1])
# a) e
# b) l
# c) H
# d) o

# Fill with the correct option: 

# Question 28
# What will be the result of the following code?
# x = 2
# y = 3
# print(x ** y)
# a) 5
# b) 8
# c) 6
# d) 9

# Fill with the correct option: 

# Question 29
# Which of the following is a correct way to create a set in Python?
# a) my_set = {1, 2, 3, 4}
# b) my_set = (1, 2, 3, 4)
# c) my_set = [1, 2, 3, 4]
# d) my_set = {1: 'a', 2: 'b', 3: 'c', 4: 'd'}

# Fill with the correct option: 

# Question 30
# What is the result of the following expression?
# True and False
# a) True
# b) False
# c) Error
# d) None

# Fill with the correct option: 

# Question 31
# What does the 'in' operator do in Python?
# a) Checks if a value exists in a list, tuple, or dictionary
# b) Adds two numbers
# c) Subtracts two numbers
# d) Returns the remainder of a division

# Fill with the correct option: 

# Question 32
# What is the output of the following code?
# x = 5
# y = 2
# print(x - y)
# a) 3
# b) 7
# c) 5
# d) 2

# Fill with the correct option: 

# Question 33
# What is the correct way to check if a key exists in a dictionary?
# a) key in dict
# b) key.exists() in dict
# c) exists(key) in dict
# d) dict.exists(key)

# Fill with the correct option: 

# Question 34
# What will the following code output?
# x = 10
# y = 3
# print(x % y)
# a) 3
# b) 0
# c) 1
# d) 2

# Fill with the correct option: 

# Question 35
# What is the output of the following code?
# x = [1, 2, 3]
# print(len(x))
# a) 1
# b) 2
# c) 3
# d) 4

# Fill with the correct option: 

# Question 36
# What does the 'not in' operator do in Python?
# a) Checks if a value does not exist in a list, tuple, or dictionary
# b) Adds two numbers
# c) Subtracts two numbers
# d) Returns the remainder of a division

# Fill with the correct option: 

# Question 37
# What will the following code output?
# x = [1, 2, 3]
# y = [1, 2, 3]
# print(x is y)
# a) True
# b) False
# c) Error
# d) None

# Fill with the correct option: 

# Question 38
# What is the output of the following code?
# x = 10
# y = 3
# print(x / y)
# a) 3.3333333333333335
# b) 3
# c) 3.0
# d) 4

# Fill with the correct option: 

# Question 39
# What is the result of the following expression?
# 5 + 2 * 3
# a) 21
# b) 11
# c) 17
# d) 9

# Fill with the correct option: 

# Question 40
# What is the correct way to define a tuple in Python?
# a) my_tuple = [1, 2, 3]
# b) my_tuple = (1, 2, 3)
# c) my_tuple = {1, 2, 3}
# d) my_tuple = {1: 'a', 2: 'b', 3: 'c'}

# Fill with the correct option:

# %%
# Question 1
# What is the correct way to declare a variable in Python?
# a) var x = 5
# b) x = 5
# c) int x = 5
# d) declare x = 5

# Fill with the correct option: b) x = 5

# Question 2
# What is the data type of the variable 'name' in the following code?
# name = "John"
# a) Integer
# b) Float
# c) String
# d) Boolean

# fill with the correct option: c) String

# Question 3
# Which of the following is a valid variable name in Python?
# a) my_variable
# b) 1_variable
# c) variable$
# d) my-variable

# Fill with the correct option: a) my_variable

# Question 4
# What will the following code output?
# x = 10
# y = 5
# print(x + y)
# a) 10
# b) 15
# c) "10 + 5"
# d) Error

# Fill with the correct option: b) 15

# Question 5
# What is the result of the following expression?
# 10 / 3
# a) 3.3333333333333335
# b) 3
# c) 3.0
# d) 4

# Fill with the correct option: c) 3.3333333333333335

# Question 6
# Which of the following is a correct Python syntax to get the last element of a list 'my_list'?
# a) my_list[-1]
# b) my_list[last()]
# c) my_list.last()
# d) my_list[0]

# Fill with the correct option: a) my_list[-1]

# Question 7
# What is the output of the following code?
# x = 5
# y = 2
# print(x ** y)
# a) 7
# b) 10
# c) 25
# d) 3

# Fill with the correct option: c) 25

# Question 8
# Which of the following data types is immutable in Python?
# a) List
# b) Dictionary
# c) Tuple
# d) Set

# Fill with the correct option: c) Tuple

# Question 9
# What does the 'not' operator do in Python?
# a) Adds two numbers
# b) Subtracts two numbers
# c) Returns the opposite boolean value
# d) Returns the remainder of a division

# Fill with the correct option: c) Returns the opposite boolean value

# Question 10
# Which of the following is not a valid Python comment?
# a) // This is a comment
# b) # This is a comment
# c) ''' This is a comment '''
# d) """ This is a comment """

# Fill with the correct option: a) // This is a comment

# Question 11
# What is the correct way to check if two variables are equal in Python?
# a) x == y
# b) x = y
# c) x != y
# d) x !== y

# Fill with the correct option: a) x == y

# Question 12
# Which of the following operators is used for exponentiation in Python?
# a) ^
# b) **
# c) //
# d) %

# Fill with the correct option: b) **

# Question 13
# What will be the result of the following code?
# x = 5
# y = 2
# print(x / y)
# a) 2.5
# b) 2
# c) 2.0
# d) 3

# Fill with the correct option: a) 2.5

# Question 14
# Which of the following data types is mutable in Python?
# a) Tuple
# b) String
# c) List
# d) Set

# Fill with the correct option: c) List

# Question 15
# What is the result of the following expression?
# True or False
# a) True
# b) False
# c) Error
# d) None

# Fill with the correct option: a) True

# Question 16
# What does the 'and' operator do in Python?
# a) Returns True if one of the operands is True
# b) Returns False if one of the operands is False
# c) Returns True if both operands are True
# d) Returns True if both operands are False

# Fill with the correct option: c) Returns True if both operands are True

# Question 17
# Which of the following is not a valid data type in Python?
# a) int
# b) real
# c) str
# d) bool

# Fill with the correct option: b) real

# Question 18
# What will the following code output?
# x = 10
# y = 3
# print(x // y)
# a) 3
# b) 3.3333333333333335
# c) 3.0
# d) 4

# Fill with the correct option: c) 3.0

# Question 19
# Which of the following is a correct way to define a multiline string in Python?
# a) "This is a multiline string."
# b) 'This is a multiline string.'
# c) """This is a multiline string."""
# d) 'This is a \n multiline string.'

# Fill with the correct option: c) """This is a multiline string."""

# Question 20
# What will be the output of the following code?
# x = 7
# if x > 5:
#     print("x is greater than 5")
# else:
#     print("x is less than or equal to 5")
# a) x is greater than 5
# b) x is less than or equal to 5
# c) Error
# d) None

# Fill with the correct option: a) x is greater than 5

# Question 21
# What will be the result of the following code?
# x = [1, 2, 3]
# y = x
# y.append(4)
# print(x)
# a) [1, 2, 3, 4]
# b) [1, 2, 3]
# c) [4]
# d) Error

# Fill with the correct

 option: a) [1, 2, 3, 4]

# Question 22
# What is the output of the following code?
# x = 10
# y = 3
# print(x % y)
# a) 3
# b) 0
# c) 1
# d) 2

# Fill with the correct option: c) 1

# Question 23
# Which of the following data types is unordered in Python?
# a) List
# b) Tuple
# c) String
# d) Dictionary

# Fill with the correct option: d) Dictionary

# Question 24
# What is the result of the following expression?
# 10 == "10"
# a) True
# b) False
# c) Error
# d) None

# Fill with the correct option: b) False

# Question 25
# What will be the output of the following code?
# x = 5
# y = 2
# print(x * y)
# a) 10
# b) 7
# c) 5
# d) 2

# Fill with the correct option: a) 10

# Question 26
# Which of the following is used for floor division in Python?
# a) /
# b) //
# c) %
# d) *

# Fill with the correct option: b) //

# Question 27
# What is the output of the following code?
# x = "Hello"
# print(x[1])
# a) e
# b) l
# c) H
# d) o

# Fill with the correct option: b) l

# Question 28
# What will be the result of the following code?
# x = 2
# y = 3
# print(x ** y)
# a) 5
# b) 8
# c) 6
# d) 9

# Fill with the correct option: d) 9

# Question 29
# Which of the following is a correct way to create a set in Python?
# a) my_set = {1, 2, 3, 4}
# b) my_set = (1, 2, 3, 4)
# c) my_set = [1, 2, 3, 4]
# d) my_set = {1: 'a', 2: 'b', 3: 'c', 4: 'd'}

# Fill with the correct option: a) my_set = {1, 2, 3, 4}

# Question 30
# What is the result of the following expression?
# True and False
# a) True
# b) False
# c) Error
# d) None

# Fill with the correct option: b) False

# Question 31
# What does the 'in' operator do in Python?
# a) Checks if a value exists in a list, tuple, or dictionary
# b) Adds two numbers
# c) Subtracts two numbers
# d) Returns the remainder of a division

# Fill with the correct option: a) Checks if a value exists in a list, tuple, or dictionary


# Question 32
# What is the output of the following code?
# x = 5
# y = 2
# print(x - y)
# a) 3
# b) 7
# c) 5
# d) 2

# Fill with the correct option: a) 3


# Question 33
# What is the correct way to check if a key exists in a dictionary?
# a) key in dict
# b) key.exists() in dict
# c) exists(key) in dict
# d) dict.exists(key)

# Fill with the correct option: a) key in dict


# Question 34
# What will the following code output?
# x = 10
# y = 3
# print(x % y)
# a) 3
# b) 0
# c) 1
# d) 2

# Fill with the correct option: c) 1


# Qusetion 35
# What is the output of the following code?
# x = [1, 2, 3]
# print(len(x))
# a) 1
# b) 2
# c) 3
# d) 4

# Fill with the correct option: c) 3


# Question 36
# What does the 'not in' operator do in Python?
# a) Checks if a value does not exist in a list, tuple, or dictionary
# b) Adds two numbers
# c) Subtracts two numbers
# d) Returns the remainder of a division

# Fill with the correct option: a) Checks if a value does not exist in a list, tuple, or dictio

# Question 37
# What will the following code output?
# x = [1, 2, 3]
# y = [1, 2, 3]
# print(x is y)
# a) True
# b) False
# c) Error
# d) None

# Fill with the correct option: b) False


# Question 38
# What is the output of the following code?
# x = 10
# y = 3
# print(x / y)
# a) 3.3333333333333335
# b) 3
# c) 3.0
# d) 4

# Fill with the correct option: a) 3.3333333333333335


# Question 39
# What is the result of the following expression?
# 5 + 2 * 3
# a) 21
# b) 11
# c) 17
# d) 9

# Fill with the correct option: c) 17


# Question 40
# What is the correct way to define a tuple in Python?
# a) my_tuple = [1, 2, 3]
# b) my_tuple = (1, 2, 3)
# c) my_tuple = {1, 2, 3}
# d) my_tuple = {1: 'a', 2: 'b', 3: 'c'}

# Fill with the correct option: b) my_tuple = (1, 2, 3)
